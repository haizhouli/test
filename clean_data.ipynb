# %%
import pandas as pd
import datetime

# %%
df_admin = pd.read_excel(r"NZ_Admin_JOBS.xlsx", header = None)

# %%
df_admin.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2  \
# 0                                       NaN
# 1                      Avenues Orthodontics
# 2                        New Zealand Police
# 3  Kew Pacific Island Early Learning Centre
# 4                                       NaN
#
#                                                    3  \
# 0  location: Bay of PlentyBay of Plentyarea: Taur...
# 1  location: Bay of PlentyBay of Plentyarea: Taur...
# 2                         location: AucklandAuckland
# 3  location: SouthlandSouthlandarea: Invercargill...
# 4  location: CanterburyCanterburyarea: Christchur...
#
#                                 4  \
# 0  Featured,at,Private Advertiser
# 1                     Featured,at
# 2                       4d ago,at
# 3                       1h ago,at
# 4    4d ago,at,Private Advertiser
#
#                                                    5
# 0  classification: Administration & Office Suppor...
# 1  classification: Administration & Office Suppor...
# 2  classification: Administration & Office Suppor...
# 3  classification: Administration & Office Suppor...
# 4  classification: Administration & Office Suppor...

# %%
df_admin.isnull().sum().sort_values(ascending=False)
# Out:
# 2    22
# 0     0
# 1     0
# 3     0
# 4     0
# 5     0
# dtype: int64

# %%
pd.set_option('display.max_colwidth', None)
df_admin[df_admin[3].str.contains(',')]
# Out:
#                                                            0  \
# 12                   Office Admin Assistant (10hrs per week)
# 17    Part-time Health & Disability Administrative Assistant
# 23                                   Reception/Administrator
# 25                                      Office Administrator
# 36                                      office administrator
# ...                                                      ...
# 2700                                     Executive Assistant
# 2701                                  Temporary Office Roles
# 2704                                     Executive Assistant
# 2705                                  Temporary Office Roles
# 2706                                  Temporary Office Roles
#
#                                                                                                               1  \
# 12    https://www.seek.co.nz/job/50597141?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 17    https://www.seek.co.nz/job/50610748?type=standout#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 23    https://www.seek.co.nz/job/50556340?type=promoted#searchRequestToken=d16e02a9-8271-468a-abe3-04a22564a452
# 25    https://www.seek.co.nz/job/50621389?type=standard#searchRequestToken=d16e02a9-8271-468a-abe3-04a22564a452
# 36    https://www.seek.co.nz/job/50621878?type=standard#searchRequestToken=d16e02a9-8271-468a-abe3-04a22564a452
# ...                                                                                                         ...
# 2700  https://www.seek.co.nz/job/50494228?type=standout#searchRequestToken=c4e3452e-0c7b-47ee-8dcd-97b653d46ce8
# 2701  https://www.seek.co.nz/job/50556279?type=standout#searchRequestToken=c4e3452e-0c7b-47ee-8dcd-97b653d46ce8
# 2704  https://www.seek.co.nz/job/50488000?type=standout#searchRequestToken=c4e3452e-0c7b-47ee-8dcd-97b653d46ce8
# 2705  https://www.seek.co.nz/job/50524865?type=standout#searchRequestToken=c4e3452e-0c7b-47ee-8dcd-97b653d46ce8
# 2706  https://www.seek.co.nz/job/50477118?type=standout#searchRequestToken=c4e3452e-0c7b-47ee-8dcd-97b653d46ce8
#
#                                                    2  \
# 12    UIV Limited - Premier Insulation North Central
# 17                                          LIFEWISE
# 23                 Fishing and Leisure Group Limited
# 25                               Brant Homes Limited
# 36                               Best Mates Pet Food
# ...                                              ...
# 2700                                  Robert Walters
# 2701                           Asset Recruitment Ltd
# 2704                          one eighty recruitment
# 2705                           Asset Recruitment Ltd
# 2706                           Asset Recruitment Ltd
#
#                                                                                                          3  \
# 12             location: AucklandAucklandarea: Manukau & East AucklandManukau & East Auckland,$20 per hour
# 17                  location: AucklandAucklandarea: Auckland CentralAuckland Central,$20 - $24.99 per hour
# 23            location: AucklandAucklandarea: Rodney & North ShoreRodney & North Shore,$19 to $22 per hour
# 25    location: AucklandAucklandarea: Manukau & East AucklandManukau & East Auckland,$20 - $24.99 per hour
# 36                      location: WaikatoWaikatoarea: Rest of WaikatoRest of Waikato,$20 - $24.99 per hour
# ...                                                                                                    ...
# 2700                                                location: WellingtonWellington,Attractive remuneration
# 2701                            location: WaikatoWaikatoarea: HamiltonHamilton,Competitive hourly rates $$
# 2704      location: WellingtonWellingtonarea: Wellington CentralWellington Central,Competitive hourly rate
# 2705                            location: WaikatoWaikatoarea: HamiltonHamilton,Competitive hourly rates $$
# 2706                            location: WaikatoWaikatoarea: HamiltonHamilton,Competitive hourly rates $$
#
#                 4                            5
# 12      8d ago,at                 $20 per hour
# 17      6d ago,at        $20 - $24.99 per hour
# 23    Featured,at          $19 to $22 per hour
# 25      4d ago,at        $20 - $24.99 per hour
# 36      4d ago,at        $20 - $24.99 per hour
# ...           ...                          ...
# 2700   26d ago,at      Attractive remuneration
# 2701   14d ago,at  Competitive hourly rates $$
# 2704   27d ago,at      Competitive hourly rate
# 2705   20d ago,at  Competitive hourly rates $$
# 2706   28d ago,at  Competitive hourly rates $$
#
# [603 rows x 6 columns]

# %%
df_admin[3] = df_admin[3].str.split(',', expand=True)[0]
df_admin[3]
# Out:
# 0                     location: Bay of PlentyBay of Plentyarea: TaurangaTauranga
# 1                     location: Bay of PlentyBay of Plentyarea: TaurangaTauranga
# 2                                                     location: AucklandAuckland
# 3                     location: SouthlandSouthlandarea: InvercargillInvercargill
# 4                   location: CanterburyCanterburyarea: ChristchurchChristchurch
#                                           ...
# 2703            location: AucklandAucklandarea: Auckland CentralAuckland Central
# 2704    location: WellingtonWellingtonarea: Wellington CentralWellington Central
# 2705                              location: WaikatoWaikatoarea: HamiltonHamilton
# 2706                              location: WaikatoWaikatoarea: HamiltonHamilton
# 2707                                              location: WellingtonWellington
# Name: 3, Length: 2708, dtype: object

# %%
df_admin[['location','area']] = df_admin[3].str.split('area:', expand=True)
df_admin
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                                                                               1  \
# 0     https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1     https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 2     https://www.seek.co.nz/job/50622169?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 3     https://www.seek.co.nz/job/50639620?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 4     https://www.seek.co.nz/job/50622432?type=standout#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# ...                                                                                                         ...
# 2703  https://www.seek.co.nz/job/50490062?type=standout#searchRequestToken=c4e3452e-0c7b-47ee-8dcd-97b653d46ce8
# 2704  https://www.seek.co.nz/job/50488000?type=standout#searchRequestToken=c4e3452e-0c7b-47ee-8dcd-97b653d46ce8
# 2705  https://www.seek.co.nz/job/50524865?type=standout#searchRequestToken=c4e3452e-0c7b-47ee-8dcd-97b653d46ce8
# 2706  https://www.seek.co.nz/job/50477118?type=standout#searchRequestToken=c4e3452e-0c7b-47ee-8dcd-97b653d46ce8
# 2707  https://www.seek.co.nz/job/50496571?type=standout#searchRequestToken=c4e3452e-0c7b-47ee-8dcd-97b653d46ce8
#
#                                              2  \
# 0                                          NaN
# 1                         Avenues Orthodontics
# 2                           New Zealand Police
# 3     Kew Pacific Island Early Learning Centre
# 4                                          NaN
# ...                                        ...
# 2703                     Hays Talent Solutions
# 2704                    one eighty recruitment
# 2705                     Asset Recruitment Ltd
# 2706                     Asset Recruitment Ltd
# 2707                    Alpha Recruitment - NZ
#
#                                                                              3  \
# 0                   location: Bay of PlentyBay of Plentyarea: TaurangaTauranga
# 1                   location: Bay of PlentyBay of Plentyarea: TaurangaTauranga
# 2                                                   location: AucklandAuckland
# 3                   location: SouthlandSouthlandarea: InvercargillInvercargill
# 4                 location: CanterburyCanterburyarea: ChristchurchChristchurch
# ...                                                                        ...
# 2703          location: AucklandAucklandarea: Auckland CentralAuckland Central
# 2704  location: WellingtonWellingtonarea: Wellington CentralWellington Central
# 2705                            location: WaikatoWaikatoarea: HamiltonHamilton
# 2706                            location: WaikatoWaikatoarea: HamiltonHamilton
# 2707                                            location: WellingtonWellington
#
#                                    4  \
# 0     Featured,at,Private Advertiser
# 1                        Featured,at
# 2                          4d ago,at
# 3                          1h ago,at
# 4       4d ago,at,Private Advertiser
# ...                              ...
# 2703                      27d ago,at
# 2704                      27d ago,at
# 2705                      20d ago,at
# 2706                      28d ago,at
# 2707                      26d ago,at
#
#                                                                                                                                                                 5  \
# 0                             classification: Administration & Office SupportAdministration & Office SupportsubClassification: Office ManagementOffice Management
# 1                                     classification: Administration & Office SupportAdministration & Office SupportsubClassification: ReceptionistsReceptionists
# 2                                                     classification: Administration & Office SupportAdministration & Office SupportsubClassification: OtherOther
# 3             classification: Administration & Office SupportAdministration & Office SupportsubClassification: Administrative AssistantsAdministrative Assistants
# 4     classification: Administration & Office SupportAdministration & Office SupportsubClassification: Client & Sales AdministrationClient & Sales Administration
# ...                                                                                                                                                           ...
# 2703  classification: Administration & Office SupportAdministration & Office SupportsubClassification: Client & Sales AdministrationClient & Sales Administration
# 2704                                                                                                                                      Competitive hourly rate
# 2705                                                                                                                                  Competitive hourly rates $$
# 2706                                                                                                                                  Competitive hourly rates $$
# 2707                    classification: Administration & Office SupportAdministration & Office SupportsubClassification: PA, EA & SecretarialPA, EA & Secretarial
#
#                                   location  \
# 0     location: Bay of PlentyBay of Plenty
# 1     location: Bay of PlentyBay of Plenty
# 2               location: AucklandAuckland
# 3             location: SouthlandSouthland
# 4           location: CanterburyCanterbury
# ...                                    ...
# 2703            location: AucklandAuckland
# 2704        location: WellingtonWellington
# 2705              location: WaikatoWaikato
# 2706              location: WaikatoWaikato
# 2707        location: WellingtonWellington
#
#                                        area
# 0                          TaurangaTauranga
# 1                          TaurangaTauranga
# 2                                      None
# 3                  InvercargillInvercargill
# 4                  ChristchurchChristchurch
# ...                                     ...
# 2703       Auckland CentralAuckland Central
# 2704   Wellington CentralWellington Central
# 2705                       HamiltonHamilton
# 2706                       HamiltonHamilton
# 2707                                   None
#
# [2708 rows x 8 columns]

# %%
df_admin['location'].isna().sum()
# Out:
# 0

# %%
df_admin['area'].isna().sum()
# Out:
# 541

# %%
df_admin['location'] = df_admin['location'].apply(lambda x:x[9:])

# %%
df_admin['location']
# Out:
# 0        Bay of PlentyBay of Plenty
# 1        Bay of PlentyBay of Plenty
# 2                  AucklandAuckland
# 3                SouthlandSouthland
# 4              CanterburyCanterbury
#                    ...
# 2703               AucklandAuckland
# 2704           WellingtonWellington
# 2705                 WaikatoWaikato
# 2706                 WaikatoWaikato
# 2707           WellingtonWellington
# Name: location, Length: 2708, dtype: object

# %%
def deduplication(x):
    mid = len(x)//2
    if x!='unknown':
        return x[:mid+1]
    else:
        return 'unknown'

# %%
def deduplication_better(x):
    trim = x.strip()
    index = (trim+trim).find(trim,1)
    if index != -1:
        return trim[:index]
    else:
        return 'unknown'

# %%
def deduplication_regex(x):
    x = x.strip()
    if x == 'None':
        return None
    return re.match(r'(.*)\1', x).group(1)

# %%
df_admin['location'] = df_admin['location'].apply(deduplication_better)

# %%
df_admin['location']
# Out:
# 0       Bay of Plenty
# 1       Bay of Plenty
# 2            Auckland
# 3           Southland
# 4          Canterbury
#             ...
# 2703         Auckland
# 2704       Wellington
# 2705          Waikato
# 2706          Waikato
# 2707       Wellington
# Name: location, Length: 2708, dtype: object

# %%
df_admin.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                                                                            1  \
# 0  https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1  https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 2  https://www.seek.co.nz/job/50622169?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 3  https://www.seek.co.nz/job/50639620?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 4  https://www.seek.co.nz/job/50622432?type=standout#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
#
#                                           2  \
# 0                                       NaN
# 1                      Avenues Orthodontics
# 2                        New Zealand Police
# 3  Kew Pacific Island Early Learning Centre
# 4                                       NaN
#
#                                                               3  \
# 0    location: Bay of PlentyBay of Plentyarea: TaurangaTauranga
# 1    location: Bay of PlentyBay of Plentyarea: TaurangaTauranga
# 2                                    location: AucklandAuckland
# 3    location: SouthlandSouthlandarea: InvercargillInvercargill
# 4  location: CanterburyCanterburyarea: ChristchurchChristchurch
#
#                                 4  \
# 0  Featured,at,Private Advertiser
# 1                     Featured,at
# 2                       4d ago,at
# 3                       1h ago,at
# 4    4d ago,at,Private Advertiser
#
#                                                                                                                                                              5  \
# 0                          classification: Administration & Office SupportAdministration & Office SupportsubClassification: Office ManagementOffice Management
# 1                                  classification: Administration & Office SupportAdministration & Office SupportsubClassification: ReceptionistsReceptionists
# 2                                                  classification: Administration & Office SupportAdministration & Office SupportsubClassification: OtherOther
# 3          classification: Administration & Office SupportAdministration & Office SupportsubClassification: Administrative AssistantsAdministrative Assistants
# 4  classification: Administration & Office SupportAdministration & Office SupportsubClassification: Client & Sales AdministrationClient & Sales Administration
#
#         location                       area
# 0  Bay of Plenty           TaurangaTauranga
# 1  Bay of Plenty           TaurangaTauranga
# 2       Auckland                       None
# 3      Southland   InvercargillInvercargill
# 4     Canterbury   ChristchurchChristchurch

# %%
df_admin['area'].isna().sum()
# Out:
# 541

# %%
df_admin['area'].fillna(value='unknown',inplace = True)

# %%
df_admin['area'] = df_admin['area'].apply(deduplication_better)

# %%
df_admin['area']
# Out:
# 0                 Tauranga
# 1                 Tauranga
# 2                  unknown
# 3             Invercargill
# 4             Christchurch
#                ...
# 2703      Auckland Central
# 2704    Wellington Central
# 2705              Hamilton
# 2706              Hamilton
# 2707               unknown
# Name: area, Length: 2708, dtype: object

# %%
df_admin.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                                                                            1  \
# 0  https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1  https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 2  https://www.seek.co.nz/job/50622169?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 3  https://www.seek.co.nz/job/50639620?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 4  https://www.seek.co.nz/job/50622432?type=standout#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
#
#                                           2  \
# 0                                       NaN
# 1                      Avenues Orthodontics
# 2                        New Zealand Police
# 3  Kew Pacific Island Early Learning Centre
# 4                                       NaN
#
#                                                               3  \
# 0    location: Bay of PlentyBay of Plentyarea: TaurangaTauranga
# 1    location: Bay of PlentyBay of Plentyarea: TaurangaTauranga
# 2                                    location: AucklandAuckland
# 3    location: SouthlandSouthlandarea: InvercargillInvercargill
# 4  location: CanterburyCanterburyarea: ChristchurchChristchurch
#
#                                 4  \
# 0  Featured,at,Private Advertiser
# 1                     Featured,at
# 2                       4d ago,at
# 3                       1h ago,at
# 4    4d ago,at,Private Advertiser
#
#                                                                                                                                                              5  \
# 0                          classification: Administration & Office SupportAdministration & Office SupportsubClassification: Office ManagementOffice Management
# 1                                  classification: Administration & Office SupportAdministration & Office SupportsubClassification: ReceptionistsReceptionists
# 2                                                  classification: Administration & Office SupportAdministration & Office SupportsubClassification: OtherOther
# 3          classification: Administration & Office SupportAdministration & Office SupportsubClassification: Administrative AssistantsAdministrative Assistants
# 4  classification: Administration & Office SupportAdministration & Office SupportsubClassification: Client & Sales AdministrationClient & Sales Administration
#
#         location          area
# 0  Bay of Plenty      Tauranga
# 1  Bay of Plenty      Tauranga
# 2       Auckland       unknown
# 3      Southland  Invercargill
# 4     Canterbury  Christchurch

# %%
df_admin['area'].isna().sum()
# Out:
# 0

# %%
df_admin.drop(3, axis = 1, inplace = True)

# %%
df_admin.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                                                                            1  \
# 0  https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1  https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 2  https://www.seek.co.nz/job/50622169?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 3  https://www.seek.co.nz/job/50639620?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 4  https://www.seek.co.nz/job/50622432?type=standout#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
#
#                                           2                               4  \
# 0                                       NaN  Featured,at,Private Advertiser
# 1                      Avenues Orthodontics                     Featured,at
# 2                        New Zealand Police                       4d ago,at
# 3  Kew Pacific Island Early Learning Centre                       1h ago,at
# 4                                       NaN    4d ago,at,Private Advertiser
#
#                                                                                                                                                              5  \
# 0                          classification: Administration & Office SupportAdministration & Office SupportsubClassification: Office ManagementOffice Management
# 1                                  classification: Administration & Office SupportAdministration & Office SupportsubClassification: ReceptionistsReceptionists
# 2                                                  classification: Administration & Office SupportAdministration & Office SupportsubClassification: OtherOther
# 3          classification: Administration & Office SupportAdministration & Office SupportsubClassification: Administrative AssistantsAdministrative Assistants
# 4  classification: Administration & Office SupportAdministration & Office SupportsubClassification: Client & Sales AdministrationClient & Sales Administration
#
#         location          area
# 0  Bay of Plenty      Tauranga
# 1  Bay of Plenty      Tauranga
# 2       Auckland       unknown
# 3      Southland  Invercargill
# 4     Canterbury  Christchurch

# %%
df_admin[['subclassification','classification']]=df_admin[5].str.split('subClassification:', expand = True)

# %%
df_admin.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2                               4  \
# 0                                       NaN  Featured,at,Private Advertiser
# 1                      Avenues Orthodontics                     Featured,at
# 2                        New Zealand Police                       4d ago,at
# 3  Kew Pacific Island Early Learning Centre                       1h ago,at
# 4                                       NaN    4d ago,at,Private Advertiser
#
#                                                    5        location  \
# 0  classification: Administration & Office Suppor...   Bay of Plenty
# 1  classification: Administration & Office Suppor...   Bay of Plenty
# 2  classification: Administration & Office Suppor...        Auckland
# 3  classification: Administration & Office Suppor...       Southland
# 4  classification: Administration & Office Suppor...      Canterbury
#
#             area                                  subclassification  \
# 0       Tauranga  classification: Administration & Office Suppor...
# 1       Tauranga  classification: Administration & Office Suppor...
# 2        unknown  classification: Administration & Office Suppor...
# 3   Invercargill  classification: Administration & Office Suppor...
# 4   Christchurch  classification: Administration & Office Suppor...
#
#                                       classification
# 0                 Office ManagementOffice Management
# 1                         ReceptionistsReceptionists
# 2                                         OtherOther
# 3   Administrative AssistantsAdministrative Assis...
# 4   Client & Sales AdministrationClient & Sales A...

# %%
df_admin['classification'].isna().sum()
# Out:
# 603

# %%
df_admin['classification'].fillna('unknown', inplace = True)

# %%
df_admin.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2                               4  \
# 0                                       NaN  Featured,at,Private Advertiser
# 1                      Avenues Orthodontics                     Featured,at
# 2                        New Zealand Police                       4d ago,at
# 3  Kew Pacific Island Early Learning Centre                       1h ago,at
# 4                                       NaN    4d ago,at,Private Advertiser
#
#                                                    5        location  \
# 0  classification: Administration & Office Suppor...   Bay of Plenty
# 1  classification: Administration & Office Suppor...   Bay of Plenty
# 2  classification: Administration & Office Suppor...        Auckland
# 3  classification: Administration & Office Suppor...       Southland
# 4  classification: Administration & Office Suppor...      Canterbury
#
#             area                                  subclassification  \
# 0       Tauranga  classification: Administration & Office Suppor...
# 1       Tauranga  classification: Administration & Office Suppor...
# 2        unknown  classification: Administration & Office Suppor...
# 3   Invercargill  classification: Administration & Office Suppor...
# 4   Christchurch  classification: Administration & Office Suppor...
#
#                                       classification
# 0                 Office ManagementOffice Management
# 1                         ReceptionistsReceptionists
# 2                                         OtherOther
# 3   Administrative AssistantsAdministrative Assis...
# 4   Client & Sales AdministrationClient & Sales A...

# %%
df_admin['classification'] = df_admin['classification'].apply(deduplication_better)

# %%
df_admin.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2                               4  \
# 0                                       NaN  Featured,at,Private Advertiser
# 1                      Avenues Orthodontics                     Featured,at
# 2                        New Zealand Police                       4d ago,at
# 3  Kew Pacific Island Early Learning Centre                       1h ago,at
# 4                                       NaN    4d ago,at,Private Advertiser
#
#                                                    5        location  \
# 0  classification: Administration & Office Suppor...   Bay of Plenty
# 1  classification: Administration & Office Suppor...   Bay of Plenty
# 2  classification: Administration & Office Suppor...        Auckland
# 3  classification: Administration & Office Suppor...       Southland
# 4  classification: Administration & Office Suppor...      Canterbury
#
#             area                                  subclassification  \
# 0       Tauranga  classification: Administration & Office Suppor...
# 1       Tauranga  classification: Administration & Office Suppor...
# 2        unknown  classification: Administration & Office Suppor...
# 3   Invercargill  classification: Administration & Office Suppor...
# 4   Christchurch  classification: Administration & Office Suppor...
#
#                    classification
# 0               Office Management
# 1                   Receptionists
# 2                           Other
# 3       Administrative Assistants
# 4   Client & Sales Administration

# %%
df_admin.drop(5, axis = 1, inplace = True)

# %%
df_admin.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2                               4  \
# 0                                       NaN  Featured,at,Private Advertiser
# 1                      Avenues Orthodontics                     Featured,at
# 2                        New Zealand Police                       4d ago,at
# 3  Kew Pacific Island Early Learning Centre                       1h ago,at
# 4                                       NaN    4d ago,at,Private Advertiser
#
#          location           area  \
# 0   Bay of Plenty       Tauranga
# 1   Bay of Plenty       Tauranga
# 2        Auckland        unknown
# 3       Southland   Invercargill
# 4      Canterbury   Christchurch
#
#                                    subclassification  \
# 0  classification: Administration & Office Suppor...
# 1  classification: Administration & Office Suppor...
# 2  classification: Administration & Office Suppor...
# 3  classification: Administration & Office Suppor...
# 4  classification: Administration & Office Suppor...
#
#                    classification
# 0               Office Management
# 1                   Receptionists
# 2                           Other
# 3       Administrative Assistants
# 4   Client & Sales Administration

# %%
df_admin[['posted time','featurned at']] = df_admin[4].str.split(',', expand = True)[[0,2]]

# %%
df_admin.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2                               4  \
# 0                                       NaN  Featured,at,Private Advertiser
# 1                      Avenues Orthodontics                     Featured,at
# 2                        New Zealand Police                       4d ago,at
# 3  Kew Pacific Island Early Learning Centre                       1h ago,at
# 4                                       NaN    4d ago,at,Private Advertiser
#
#          location           area  \
# 0   Bay of Plenty       Tauranga
# 1   Bay of Plenty       Tauranga
# 2        Auckland        unknown
# 3       Southland   Invercargill
# 4      Canterbury   Christchurch
#
#                                    subclassification  \
# 0  classification: Administration & Office Suppor...
# 1  classification: Administration & Office Suppor...
# 2  classification: Administration & Office Suppor...
# 3  classification: Administration & Office Suppor...
# 4  classification: Administration & Office Suppor...
#
#                    classification posted time        featurned at
# 0               Office Management    Featured  Private Advertiser
# 1                   Receptionists    Featured                None
# 2                           Other      4d ago                None
# 3       Administrative Assistants      1h ago                None
# 4   Client & Sales Administration      4d ago  Private Advertiser

# %%
df_admin.drop(4, axis = 1, inplace = True)

# %%
df_admin['featurned at'].isna().sum()
# Out:
# 2686

# %%
df_admin['featurned at'].fillna('unknown', inplace = True)

# %%
df_admin
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                       1  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                              2        location  \
# 0                                          NaN   Bay of Plenty
# 1                         Avenues Orthodontics   Bay of Plenty
# 2                           New Zealand Police        Auckland
# 3     Kew Pacific Island Early Learning Centre       Southland
# 4                                          NaN      Canterbury
# ...                                        ...             ...
# 2703                     Hays Talent Solutions        Auckland
# 2704                    one eighty recruitment      Wellington
# 2705                     Asset Recruitment Ltd         Waikato
# 2706                     Asset Recruitment Ltd         Waikato
# 2707                    Alpha Recruitment - NZ      Wellington
#
#                                  area  \
# 0                            Tauranga
# 1                            Tauranga
# 2                             unknown
# 3                        Invercargill
# 4                        Christchurch
# ...                               ...
# 2703                 Auckland Central
# 2704   Wellington CentralWellington C
# 2705           HamiltonHamilton,Compe
# 2706           HamiltonHamilton,Compe
# 2707                          unknown
#
#                                       subclassification  \
# 0     classification: Administration & Office Suppor...
# 1     classification: Administration & Office Suppor...
# 2     classification: Administration & Office Suppor...
# 3     classification: Administration & Office Suppor...
# 4     classification: Administration & Office Suppor...
# ...                                                 ...
# 2703  classification: Administration & Office Suppor...
# 2704                            Competitive hourly rate
# 2705                        Competitive hourly rates $$
# 2706                        Competitive hourly rates $$
# 2707  classification: Administration & Office Suppor...
#
#                       classification posted time        featurned at
# 0                  Office Management    Featured  Private Advertiser
# 1                      Receptionists    Featured             unknown
# 2                              Other      4d ago             unknown
# 3          Administrative Assistants      1h ago             unknown
# 4      Client & Sales Administration      4d ago  Private Advertiser
# ...                              ...         ...                 ...
# 2703   Client & Sales Administration     27d ago             unknown
# 2704                         unknown     27d ago             unknown
# 2705                         unknown     20d ago             unknown
# 2706                         unknown     28d ago             unknown
# 2707            PA, EA & Secretarial     26d ago             unknown
#
# [2708 rows x 9 columns]

# %%
def apply_salary(x):
    if 'classification:' in x:
        return 'unknown'
    else:
        return x

# %%
df_admin['salary'] = df_admin['subclassification'].apply(apply_salary)

# %%
df_admin
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                       1  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                              2        location  \
# 0                                          NaN   Bay of Plenty
# 1                         Avenues Orthodontics   Bay of Plenty
# 2                           New Zealand Police        Auckland
# 3     Kew Pacific Island Early Learning Centre       Southland
# 4                                          NaN      Canterbury
# ...                                        ...             ...
# 2703                     Hays Talent Solutions        Auckland
# 2704                    one eighty recruitment      Wellington
# 2705                     Asset Recruitment Ltd         Waikato
# 2706                     Asset Recruitment Ltd         Waikato
# 2707                    Alpha Recruitment - NZ      Wellington
#
#                                  area  \
# 0                            Tauranga
# 1                            Tauranga
# 2                             unknown
# 3                        Invercargill
# 4                        Christchurch
# ...                               ...
# 2703                 Auckland Central
# 2704   Wellington CentralWellington C
# 2705           HamiltonHamilton,Compe
# 2706           HamiltonHamilton,Compe
# 2707                          unknown
#
#                                       subclassification  \
# 0     classification: Administration & Office Suppor...
# 1     classification: Administration & Office Suppor...
# 2     classification: Administration & Office Suppor...
# 3     classification: Administration & Office Suppor...
# 4     classification: Administration & Office Suppor...
# ...                                                 ...
# 2703  classification: Administration & Office Suppor...
# 2704                            Competitive hourly rate
# 2705                        Competitive hourly rates $$
# 2706                        Competitive hourly rates $$
# 2707  classification: Administration & Office Suppor...
#
#                       classification posted time        featurned at  \
# 0                  Office Management    Featured  Private Advertiser
# 1                      Receptionists    Featured             unknown
# 2                              Other      4d ago             unknown
# 3          Administrative Assistants      1h ago             unknown
# 4      Client & Sales Administration      4d ago  Private Advertiser
# ...                              ...         ...                 ...
# 2703   Client & Sales Administration     27d ago             unknown
# 2704                         unknown     27d ago             unknown
# 2705                         unknown     20d ago             unknown
# 2706                         unknown     28d ago             unknown
# 2707            PA, EA & Secretarial     26d ago             unknown
#
#                            salary
# 0                         unknown
# 1                         unknown
# 2                         unknown
# 3                         unknown
# 4                         unknown
# ...                           ...
# 2703                      unknown
# 2704      Competitive hourly rate
# 2705  Competitive hourly rates $$
# 2706  Competitive hourly rates $$
# 2707                      unknown
#
# [2708 rows x 10 columns]

# %%
def apply_classification(x):
    if 'classification' in x:
        return x[15:]
    else:
        return 'unknown'

# %%
df_admin['subclassification']=df_admin['subclassification'].apply(apply_classification)

# %%
df_admin
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                       1  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                              2        location  \
# 0                                          NaN   Bay of Plenty
# 1                         Avenues Orthodontics   Bay of Plenty
# 2                           New Zealand Police        Auckland
# 3     Kew Pacific Island Early Learning Centre       Southland
# 4                                          NaN      Canterbury
# ...                                        ...             ...
# 2703                     Hays Talent Solutions        Auckland
# 2704                    one eighty recruitment      Wellington
# 2705                     Asset Recruitment Ltd         Waikato
# 2706                     Asset Recruitment Ltd         Waikato
# 2707                    Alpha Recruitment - NZ      Wellington
#
#                                  area  \
# 0                            Tauranga
# 1                            Tauranga
# 2                             unknown
# 3                        Invercargill
# 4                        Christchurch
# ...                               ...
# 2703                 Auckland Central
# 2704   Wellington CentralWellington C
# 2705           HamiltonHamilton,Compe
# 2706           HamiltonHamilton,Compe
# 2707                          unknown
#
#                                       subclassification  \
# 0      Administration & Office SupportAdministration...
# 1      Administration & Office SupportAdministration...
# 2      Administration & Office SupportAdministration...
# 3      Administration & Office SupportAdministration...
# 4      Administration & Office SupportAdministration...
# ...                                                 ...
# 2703   Administration & Office SupportAdministration...
# 2704                                            unknown
# 2705                                            unknown
# 2706                                            unknown
# 2707   Administration & Office SupportAdministration...
#
#                       classification posted time        featurned at  \
# 0                  Office Management    Featured  Private Advertiser
# 1                      Receptionists    Featured             unknown
# 2                              Other      4d ago             unknown
# 3          Administrative Assistants      1h ago             unknown
# 4      Client & Sales Administration      4d ago  Private Advertiser
# ...                              ...         ...                 ...
# 2703   Client & Sales Administration     27d ago             unknown
# 2704                         unknown     27d ago             unknown
# 2705                         unknown     20d ago             unknown
# 2706                         unknown     28d ago             unknown
# 2707            PA, EA & Secretarial     26d ago             unknown
#
#                            salary
# 0                         unknown
# 1                         unknown
# 2                         unknown
# 3                         unknown
# 4                         unknown
# ...                           ...
# 2703                      unknown
# 2704      Competitive hourly rate
# 2705  Competitive hourly rates $$
# 2706  Competitive hourly rates $$
# 2707                      unknown
#
# [2708 rows x 10 columns]

# %%
df_admin.rename(columns ={0:'Job title',1:'website',2:'company name'}, inplace = True )

# %%
df_admin
# Out:
#                                  Job title  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                 website  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                   company name        location  \
# 0                                          NaN   Bay of Plenty
# 1                         Avenues Orthodontics   Bay of Plenty
# 2                           New Zealand Police        Auckland
# 3     Kew Pacific Island Early Learning Centre       Southland
# 4                                          NaN      Canterbury
# ...                                        ...             ...
# 2703                     Hays Talent Solutions        Auckland
# 2704                    one eighty recruitment      Wellington
# 2705                     Asset Recruitment Ltd         Waikato
# 2706                     Asset Recruitment Ltd         Waikato
# 2707                    Alpha Recruitment - NZ      Wellington
#
#                                  area  \
# 0                            Tauranga
# 1                            Tauranga
# 2                             unknown
# 3                        Invercargill
# 4                        Christchurch
# ...                               ...
# 2703                 Auckland Central
# 2704   Wellington CentralWellington C
# 2705           HamiltonHamilton,Compe
# 2706           HamiltonHamilton,Compe
# 2707                          unknown
#
#                                       subclassification  \
# 0      Administration & Office SupportAdministration...
# 1      Administration & Office SupportAdministration...
# 2      Administration & Office SupportAdministration...
# 3      Administration & Office SupportAdministration...
# 4      Administration & Office SupportAdministration...
# ...                                                 ...
# 2703   Administration & Office SupportAdministration...
# 2704                                            unknown
# 2705                                            unknown
# 2706                                            unknown
# 2707   Administration & Office SupportAdministration...
#
#                       classification posted time        featurned at  \
# 0                  Office Management    Featured  Private Advertiser
# 1                      Receptionists    Featured             unknown
# 2                              Other      4d ago             unknown
# 3          Administrative Assistants      1h ago             unknown
# 4      Client & Sales Administration      4d ago  Private Advertiser
# ...                              ...         ...                 ...
# 2703   Client & Sales Administration     27d ago             unknown
# 2704                         unknown     27d ago             unknown
# 2705                         unknown     20d ago             unknown
# 2706                         unknown     28d ago             unknown
# 2707            PA, EA & Secretarial     26d ago             unknown
#
#                            salary
# 0                         unknown
# 1                         unknown
# 2                         unknown
# 3                         unknown
# 4                         unknown
# ...                           ...
# 2703                      unknown
# 2704      Competitive hourly rate
# 2705  Competitive hourly rates $$
# 2706  Competitive hourly rates $$
# 2707                      unknown
#
# [2708 rows x 10 columns]

# %%
df_admin[['classification1','classification2','classification3']] = df_admin['subclassification'].str.split('&', expand = True).fillna('unknown')

# %%
df_admin
# Out:
#                                  Job title  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                 website  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                   company name        location  \
# 0                                          NaN   Bay of Plenty
# 1                         Avenues Orthodontics   Bay of Plenty
# 2                           New Zealand Police        Auckland
# 3     Kew Pacific Island Early Learning Centre       Southland
# 4                                          NaN      Canterbury
# ...                                        ...             ...
# 2703                     Hays Talent Solutions        Auckland
# 2704                    one eighty recruitment      Wellington
# 2705                     Asset Recruitment Ltd         Waikato
# 2706                     Asset Recruitment Ltd         Waikato
# 2707                    Alpha Recruitment - NZ      Wellington
#
#                                  area  \
# 0                            Tauranga
# 1                            Tauranga
# 2                             unknown
# 3                        Invercargill
# 4                        Christchurch
# ...                               ...
# 2703                 Auckland Central
# 2704   Wellington CentralWellington C
# 2705           HamiltonHamilton,Compe
# 2706           HamiltonHamilton,Compe
# 2707                          unknown
#
#                                       subclassification  \
# 0      Administration & Office SupportAdministration...
# 1      Administration & Office SupportAdministration...
# 2      Administration & Office SupportAdministration...
# 3      Administration & Office SupportAdministration...
# 4      Administration & Office SupportAdministration...
# ...                                                 ...
# 2703   Administration & Office SupportAdministration...
# 2704                                            unknown
# 2705                                            unknown
# 2706                                            unknown
# 2707   Administration & Office SupportAdministration...
#
#                       classification posted time        featurned at  \
# 0                  Office Management    Featured  Private Advertiser
# 1                      Receptionists    Featured             unknown
# 2                              Other      4d ago             unknown
# 3          Administrative Assistants      1h ago             unknown
# 4      Client & Sales Administration      4d ago  Private Advertiser
# ...                              ...         ...                 ...
# 2703   Client & Sales Administration     27d ago             unknown
# 2704                         unknown     27d ago             unknown
# 2705                         unknown     20d ago             unknown
# 2706                         unknown     28d ago             unknown
# 2707            PA, EA & Secretarial     26d ago             unknown
#
#                            salary   classification1  \
# 0                         unknown   Administration
# 1                         unknown   Administration
# 2                         unknown   Administration
# 3                         unknown   Administration
# 4                         unknown   Administration
# ...                           ...               ...
# 2703                      unknown   Administration
# 2704      Competitive hourly rate           unknown
# 2705  Competitive hourly rates $$           unknown
# 2706  Competitive hourly rates $$           unknown
# 2707                      unknown   Administration
#
#                      classification2  classification3
# 0      Office SupportAdministration    Office Support
# 1      Office SupportAdministration    Office Support
# 2      Office SupportAdministration    Office Support
# 3      Office SupportAdministration    Office Support
# 4      Office SupportAdministration    Office Support
# ...                              ...              ...
# 2703   Office SupportAdministration    Office Support
# 2704                         unknown          unknown
# 2705                         unknown          unknown
# 2706                         unknown          unknown
# 2707   Office SupportAdministration    Office Support
#
# [2708 rows x 13 columns]

# %%
df_admin.drop('subclassification', axis = 1, inplace = True)

# %%
df_admin
# Out:
#                                  Job title  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                 website  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                   company name        location  \
# 0                                          NaN   Bay of Plenty
# 1                         Avenues Orthodontics   Bay of Plenty
# 2                           New Zealand Police        Auckland
# 3     Kew Pacific Island Early Learning Centre       Southland
# 4                                          NaN      Canterbury
# ...                                        ...             ...
# 2703                     Hays Talent Solutions        Auckland
# 2704                    one eighty recruitment      Wellington
# 2705                     Asset Recruitment Ltd         Waikato
# 2706                     Asset Recruitment Ltd         Waikato
# 2707                    Alpha Recruitment - NZ      Wellington
#
#                                  area                  classification  \
# 0                            Tauranga               Office Management
# 1                            Tauranga                   Receptionists
# 2                             unknown                           Other
# 3                        Invercargill       Administrative Assistants
# 4                        Christchurch   Client & Sales Administration
# ...                               ...                             ...
# 2703                 Auckland Central   Client & Sales Administration
# 2704   Wellington CentralWellington C                         unknown
# 2705           HamiltonHamilton,Compe                         unknown
# 2706           HamiltonHamilton,Compe                         unknown
# 2707                          unknown            PA, EA & Secretarial
#
#      posted time        featurned at                       salary  \
# 0       Featured  Private Advertiser                      unknown
# 1       Featured             unknown                      unknown
# 2         4d ago             unknown                      unknown
# 3         1h ago             unknown                      unknown
# 4         4d ago  Private Advertiser                      unknown
# ...          ...                 ...                          ...
# 2703     27d ago             unknown                      unknown
# 2704     27d ago             unknown      Competitive hourly rate
# 2705     20d ago             unknown  Competitive hourly rates $$
# 2706     28d ago             unknown  Competitive hourly rates $$
# 2707     26d ago             unknown                      unknown
#
#        classification1                 classification2  classification3
# 0      Administration    Office SupportAdministration    Office Support
# 1      Administration    Office SupportAdministration    Office Support
# 2      Administration    Office SupportAdministration    Office Support
# 3      Administration    Office SupportAdministration    Office Support
# 4      Administration    Office SupportAdministration    Office Support
# ...                ...                             ...              ...
# 2703   Administration    Office SupportAdministration    Office Support
# 2704           unknown                         unknown          unknown
# 2705           unknown                         unknown          unknown
# 2706           unknown                         unknown          unknown
# 2707   Administration    Office SupportAdministration    Office Support
#
# [2708 rows x 12 columns]

# %%
df_admin['company name'].fillna(df_admin['featurned at'], inplace = True)

# %%
df_admin
# Out:
#                                  Job title  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                 website  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                   company name        location  \
# 0                           Private Advertiser   Bay of Plenty
# 1                         Avenues Orthodontics   Bay of Plenty
# 2                           New Zealand Police        Auckland
# 3     Kew Pacific Island Early Learning Centre       Southland
# 4                           Private Advertiser      Canterbury
# ...                                        ...             ...
# 2703                     Hays Talent Solutions        Auckland
# 2704                    one eighty recruitment      Wellington
# 2705                     Asset Recruitment Ltd         Waikato
# 2706                     Asset Recruitment Ltd         Waikato
# 2707                    Alpha Recruitment - NZ      Wellington
#
#                                  area                  classification  \
# 0                            Tauranga               Office Management
# 1                            Tauranga                   Receptionists
# 2                             unknown                           Other
# 3                        Invercargill       Administrative Assistants
# 4                        Christchurch   Client & Sales Administration
# ...                               ...                             ...
# 2703                 Auckland Central   Client & Sales Administration
# 2704   Wellington CentralWellington C                         unknown
# 2705           HamiltonHamilton,Compe                         unknown
# 2706           HamiltonHamilton,Compe                         unknown
# 2707                          unknown            PA, EA & Secretarial
#
#      posted time        featurned at                       salary  \
# 0       Featured  Private Advertiser                      unknown
# 1       Featured             unknown                      unknown
# 2         4d ago             unknown                      unknown
# 3         1h ago             unknown                      unknown
# 4         4d ago  Private Advertiser                      unknown
# ...          ...                 ...                          ...
# 2703     27d ago             unknown                      unknown
# 2704     27d ago             unknown      Competitive hourly rate
# 2705     20d ago             unknown  Competitive hourly rates $$
# 2706     28d ago             unknown  Competitive hourly rates $$
# 2707     26d ago             unknown                      unknown
#
#        classification1                 classification2  classification3
# 0      Administration    Office SupportAdministration    Office Support
# 1      Administration    Office SupportAdministration    Office Support
# 2      Administration    Office SupportAdministration    Office Support
# 3      Administration    Office SupportAdministration    Office Support
# 4      Administration    Office SupportAdministration    Office Support
# ...                ...                             ...              ...
# 2703   Administration    Office SupportAdministration    Office Support
# 2704           unknown                         unknown          unknown
# 2705           unknown                         unknown          unknown
# 2706           unknown                         unknown          unknown
# 2707   Administration    Office SupportAdministration    Office Support
#
# [2708 rows x 12 columns]

# %%
df_admin.drop('featurned at', axis = 1, inplace = True)

# %%
df_admin
# Out:
#                                  Job title  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                 website  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                   company name        location  \
# 0                           Private Advertiser   Bay of Plenty
# 1                         Avenues Orthodontics   Bay of Plenty
# 2                           New Zealand Police        Auckland
# 3     Kew Pacific Island Early Learning Centre       Southland
# 4                           Private Advertiser      Canterbury
# ...                                        ...             ...
# 2703                     Hays Talent Solutions        Auckland
# 2704                    one eighty recruitment      Wellington
# 2705                     Asset Recruitment Ltd         Waikato
# 2706                     Asset Recruitment Ltd         Waikato
# 2707                    Alpha Recruitment - NZ      Wellington
#
#                                  area                  classification  \
# 0                            Tauranga               Office Management
# 1                            Tauranga                   Receptionists
# 2                             unknown                           Other
# 3                        Invercargill       Administrative Assistants
# 4                        Christchurch   Client & Sales Administration
# ...                               ...                             ...
# 2703                 Auckland Central   Client & Sales Administration
# 2704   Wellington CentralWellington C                         unknown
# 2705           HamiltonHamilton,Compe                         unknown
# 2706           HamiltonHamilton,Compe                         unknown
# 2707                          unknown            PA, EA & Secretarial
#
#      posted time                       salary   classification1  \
# 0       Featured                      unknown   Administration
# 1       Featured                      unknown   Administration
# 2         4d ago                      unknown   Administration
# 3         1h ago                      unknown   Administration
# 4         4d ago                      unknown   Administration
# ...          ...                          ...               ...
# 2703     27d ago                      unknown   Administration
# 2704     27d ago      Competitive hourly rate           unknown
# 2705     20d ago  Competitive hourly rates $$           unknown
# 2706     28d ago  Competitive hourly rates $$           unknown
# 2707     26d ago                      unknown   Administration
#
#                      classification2  classification3
# 0      Office SupportAdministration    Office Support
# 1      Office SupportAdministration    Office Support
# 2      Office SupportAdministration    Office Support
# 3      Office SupportAdministration    Office Support
# 4      Office SupportAdministration    Office Support
# ...                              ...              ...
# 2703   Office SupportAdministration    Office Support
# 2704                         unknown          unknown
# 2705                         unknown          unknown
# 2706                         unknown          unknown
# 2707   Office SupportAdministration    Office Support
#
# [2708 rows x 11 columns]

# %%
df_admin['posted time']=df_admin['posted time'].str.extract('(\d+[a-z])')

# %%
df_admin
# Out:
#                                  Job title  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                 website  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                   company name        location  \
# 0                           Private Advertiser   Bay of Plenty
# 1                         Avenues Orthodontics   Bay of Plenty
# 2                           New Zealand Police        Auckland
# 3     Kew Pacific Island Early Learning Centre       Southland
# 4                           Private Advertiser      Canterbury
# ...                                        ...             ...
# 2703                     Hays Talent Solutions        Auckland
# 2704                    one eighty recruitment      Wellington
# 2705                     Asset Recruitment Ltd         Waikato
# 2706                     Asset Recruitment Ltd         Waikato
# 2707                    Alpha Recruitment - NZ      Wellington
#
#                                  area                  classification  \
# 0                            Tauranga               Office Management
# 1                            Tauranga                   Receptionists
# 2                             unknown                           Other
# 3                        Invercargill       Administrative Assistants
# 4                        Christchurch   Client & Sales Administration
# ...                               ...                             ...
# 2703                 Auckland Central   Client & Sales Administration
# 2704   Wellington CentralWellington C                         unknown
# 2705           HamiltonHamilton,Compe                         unknown
# 2706           HamiltonHamilton,Compe                         unknown
# 2707                          unknown            PA, EA & Secretarial
#
#      posted time                       salary   classification1  \
# 0            NaN                      unknown   Administration
# 1            NaN                      unknown   Administration
# 2             4d                      unknown   Administration
# 3             1h                      unknown   Administration
# 4             4d                      unknown   Administration
# ...          ...                          ...               ...
# 2703         27d                      unknown   Administration
# 2704         27d      Competitive hourly rate           unknown
# 2705         20d  Competitive hourly rates $$           unknown
# 2706         28d  Competitive hourly rates $$           unknown
# 2707         26d                      unknown   Administration
#
#                      classification2  classification3
# 0      Office SupportAdministration    Office Support
# 1      Office SupportAdministration    Office Support
# 2      Office SupportAdministration    Office Support
# 3      Office SupportAdministration    Office Support
# 4      Office SupportAdministration    Office Support
# ...                              ...              ...
# 2703   Office SupportAdministration    Office Support
# 2704                         unknown          unknown
# 2705                         unknown          unknown
# 2706                         unknown          unknown
# 2707   Office SupportAdministration    Office Support
#
# [2708 rows x 11 columns]

# %%
df_admin['posted time'].fillna('unknown', inplace = True)

# %%
df_admin
# Out:
#                                  Job title  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                 website  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                   company name        location  \
# 0                           Private Advertiser   Bay of Plenty
# 1                         Avenues Orthodontics   Bay of Plenty
# 2                           New Zealand Police        Auckland
# 3     Kew Pacific Island Early Learning Centre       Southland
# 4                           Private Advertiser      Canterbury
# ...                                        ...             ...
# 2703                     Hays Talent Solutions        Auckland
# 2704                    one eighty recruitment      Wellington
# 2705                     Asset Recruitment Ltd         Waikato
# 2706                     Asset Recruitment Ltd         Waikato
# 2707                    Alpha Recruitment - NZ      Wellington
#
#                                  area                  classification  \
# 0                            Tauranga               Office Management
# 1                            Tauranga                   Receptionists
# 2                             unknown                           Other
# 3                        Invercargill       Administrative Assistants
# 4                        Christchurch   Client & Sales Administration
# ...                               ...                             ...
# 2703                 Auckland Central   Client & Sales Administration
# 2704   Wellington CentralWellington C                         unknown
# 2705           HamiltonHamilton,Compe                         unknown
# 2706           HamiltonHamilton,Compe                         unknown
# 2707                          unknown            PA, EA & Secretarial
#
#      posted time                       salary   classification1  \
# 0        unknown                      unknown   Administration
# 1        unknown                      unknown   Administration
# 2             4d                      unknown   Administration
# 3             1h                      unknown   Administration
# 4             4d                      unknown   Administration
# ...          ...                          ...               ...
# 2703         27d                      unknown   Administration
# 2704         27d      Competitive hourly rate           unknown
# 2705         20d  Competitive hourly rates $$           unknown
# 2706         28d  Competitive hourly rates $$           unknown
# 2707         26d                      unknown   Administration
#
#                      classification2  classification3
# 0      Office SupportAdministration    Office Support
# 1      Office SupportAdministration    Office Support
# 2      Office SupportAdministration    Office Support
# 3      Office SupportAdministration    Office Support
# 4      Office SupportAdministration    Office Support
# ...                              ...              ...
# 2703   Office SupportAdministration    Office Support
# 2704                         unknown          unknown
# 2705                         unknown          unknown
# 2706                         unknown          unknown
# 2707   Office SupportAdministration    Office Support
#
# [2708 rows x 11 columns]

# %%
df_admin['posted time']=df_admin['posted time'].astype('string')

# %%
def apply_posted_time(x):
    if 'd' in x:
        return -int(x[:-1])
    if 'm' in x:
        return -(int(x[:-1])*30)
    else:
        return 0

# %%
df_admin['posted time']=df_admin['posted time'].apply(apply_posted_time)

# %%
df_admin[df_admin['salary'].str.contains('\d',na=False)]['salary']
# Out:
# 12                                           $20 per hour
# 17                                  $20 - $24.99 per hour
# 23                                    $19 to $22 per hour
# 25                                  $20 - $24.99 per hour
# 36                                  $20 - $24.99 per hour
# 42                                      $40,000 - $49,999
# 48                                           $25 per hour
# 58                            $60 000 - $70 000 per annum
# 59                                        $20.00 per hour
# 66                                  $20 - $24.99 per hour
# 75                                      $55,000 - $69,999
# 77                                       $20.00 per hour.
# 78                                  $20 - $24.99 per hour
# 81                                           $21 per hour
# 82                                      $55,000 - $64,999
# 89                        $50,000 - $55,000 plus benefits
# 97                                      $45,000 - $49,999
# 103                  $55,000 - $60,000 per annum pro rata
# 112                                 $20 - $24.99 per hour
# 114                                 $20 - $24.99 per hour
# 123                                     $48,835 - $63,221
# 134                                 $20 - $29.99 per hour
# 148                                               $24-$28
# 156                                           Up to $27ph
# 165                       $50,000 - $55,000 plus benefits
# 171                                 $20 - $29.99 per hour
# 173                                 $20 - $29.99 per hour
# 191                                 $20 - $24.99 per hour
# 201                                        8% holiday pay
# 212                                     $55,000 - $64,999
# 214                                     $40,000 - $49,999
# 219                                     $45,000 - $59,999
# 231                                NZD25 - NZD28 per hour
# 247                                 $20 - $24.99 per hour
# 264                                     $45,000 - $49,999
# 277                                          $22 per hour
# 278                                    NZD75000 per annum
# 282                                 $20 - $24.99 per hour
# 306                                      $75k - $85k p.a.
# 311                           $24 - $25 + 8% holiday pay!
# 318                                     $40,000 - $49,999
# 319                                    $50,000 per annum.
# 346                                     $55,000 - $64,999
# 349                                    $20 - $25 per hour
# 379                                 $20 - $24.99 per hour
# 384                       $30 - $38 p.h. + 8% Holiday Pay
# 393                                           $45-$55,000
# 398                                     $50,000 - $54,999
# 403                     Up to $23 p.h. + + 8% Holiday Pay
# 405                                     Up to $22.00 p.h.
# 430         NZD69,726-94,127p.a.+Retirement contributions
# 442                    $60k-$70k depending on experience!
# 444                                   $22.00 - $23.00 phr
# 455                                     $40,000 - $49,999
# 458                       $27 - $33 p.h. + 8% holiday pay
# 459                      $60K - $80K experience dependent
# 464                                   $19 to $22 per hour
# 473     $60 - $65k + Career Progression to QS / leader...
# 478                                 $35 - $39.99 per hour
# 482                                     $55,000 - $64,999
# 494        $20 - $24.99 per hour dependent on experience.
# 503                       Up to $27 p.h. + 8% Holiday Pay
# 517                                 $20 - $24.99 per hour
# 530                                NZD19 - NZD23 per hour
# 532                                            $60,000 pa
# 533                                     $40,000 - $49,999
# 536                       $21 - $25 p.h. + 8% Holiday Pay
# 546                                     $60,000 - $69,999
# 550                                      $21-$23 per hour
# 558                                     $50,000 - $59,999
# 560                                    $40 - $45 per hour
# 569                              $18.50 - $23.50 per hour
# 575                                                 $25.5
# 578                       Up to $35 p.h. + 8% Holiday Pay
# 579                       $21 - $22 p.h. + 8% Holiday Pay
# 582                                NZD25 - NZD30 per hour
# 590                                 $25 - $29.99 per hour
# 612                                     $50,000 - $69,999
# 625                                     $50,000 - $59,999
# 629                                 $25 - $29.99 per hour
# 632                                     $50,000 - $64,999
# 633                                    $20 - $40 per hour
# 641                                     $48,000 - $55,000
# 644                     $50k - $65k p.a. + plus kiwisaver
# 650                                        $70-$80k+Super
# 653                                    $20 - $30 per hour
# 656                                     $45,000 - $54,999
# 660     $55,000 - $65,000 depending on relevant experi...
# 663                                     $70-75k per annum
# 679             $45,000 - $55,000 depending on experience
# 682                      $24 - $28 p.h.  + 8% Holiday Pay
# 683                     $35 - $40 p.h. + + 8% Holiday Pay
# 695                                             Circa 50k
# 1936                     $24 - $28 p.h.  + 8% Holiday Pay
# 1937                    $35 - $40 p.h. + + 8% Holiday Pay
# 1949                                            Circa 50k
# Name: salary, dtype: object

# %%
df_admin[df_admin['salary'].str.contains('\dk',na=False)]['salary']
# Out:
# 306                                      $75k - $85k p.a.
# 442                    $60k-$70k depending on experience!
# 473     $60 - $65k + Career Progression to QS / leader...
# 644                     $50k - $65k p.a. + plus kiwisaver
# 650                                        $70-$80k+Super
# 663                                     $70-75k per annum
# 695                                             Circa 50k
# 1949                                            Circa 50k
# Name: salary, dtype: object

# %%
df_admin['salary']=df_admin[df_admin['salary'].str.contains('\d', na=False)]['salary'].str.replace(' to ','-',regex=True)

# %%
df_admin[df_admin['salary'].str.contains('\d\%',na=False)]['salary'].head(100)
# Out:
# 201                        8% holiday pay
# 311           $24 - $25 + 8% holiday pay!
# 384       $30 - $38 p.h. + 8% Holiday Pay
# 403        Up-$23 p.h. + + 8% Holiday Pay
# 458       $27 - $33 p.h. + 8% holiday pay
# 503          Up-$27 p.h. + 8% Holiday Pay
# 536       $21 - $25 p.h. + 8% Holiday Pay
# 578          Up-$35 p.h. + 8% Holiday Pay
# 579       $21 - $22 p.h. + 8% Holiday Pay
# 682      $24 - $28 p.h.  + 8% Holiday Pay
# 683     $35 - $40 p.h. + + 8% Holiday Pay
# 1936     $24 - $28 p.h.  + 8% Holiday Pay
# 1937    $35 - $40 p.h. + + 8% Holiday Pay
# Name: salary, dtype: object

# %%
df_admin[df_admin['salary'].str.contains('\dk',na=False)]['salary']
# Out:
# 306                                    $75k - $85k p.a.
# 442                  $60k-$70k depending on experience!
# 473     $60 - $65k + Career Progression-QS / leadership
# 644                   $50k - $65k p.a. + plus kiwisaver
# 650                                      $70-$80k+Super
# 663                                   $70-75k per annum
# 695                                           Circa 50k
# 1949                                          Circa 50k
# Name: salary, dtype: object

# %%
df_admin['salary']=df_admin[df_admin['salary'].str.contains('\d', na=False)]['salary'].str.replace('\d\%','',regex=True)

# %%
df_admin['salary']=df_admin[df_admin['salary'].str.contains('\d', na=False)]['salary'].str.replace(',','',regex=True)

# %%
df_admin[df_admin['salary'].str.contains('\d',na=False)]['salary'].head(100)
# Out:
# 12                                          $20 per hour
# 17                                 $20 - $24.99 per hour
# 23                                      $19-$22 per hour
# 25                                 $20 - $24.99 per hour
# 36                                 $20 - $24.99 per hour
# 42                                       $40000 - $49999
# 48                                          $25 per hour
# 58                           $60 000 - $70 000 per annum
# 59                                       $20.00 per hour
# 66                                 $20 - $24.99 per hour
# 75                                       $55000 - $69999
# 77                                      $20.00 per hour.
# 78                                 $20 - $24.99 per hour
# 81                                          $21 per hour
# 82                                       $55000 - $64999
# 89                         $50000 - $55000 plus benefits
# 97                                       $45000 - $49999
# 103                   $55000 - $60000 per annum pro rata
# 112                                $20 - $24.99 per hour
# 114                                $20 - $24.99 per hour
# 123                                      $48835 - $63221
# 134                                $20 - $29.99 per hour
# 148                                              $24-$28
# 156                                             Up-$27ph
# 165                        $50000 - $55000 plus benefits
# 171                                $20 - $29.99 per hour
# 173                                $20 - $29.99 per hour
# 191                                $20 - $24.99 per hour
# 212                                      $55000 - $64999
# 214                                      $40000 - $49999
# 219                                      $45000 - $59999
# 231                               NZD25 - NZD28 per hour
# 247                                $20 - $24.99 per hour
# 264                                      $45000 - $49999
# 277                                         $22 per hour
# 278                                   NZD75000 per annum
# 282                                $20 - $24.99 per hour
# 306                                     $75k - $85k p.a.
# 311                            $24 - $25 +  holiday pay!
# 318                                      $40000 - $49999
# 319                                    $50000 per annum.
# 346                                      $55000 - $64999
# 349                                   $20 - $25 per hour
# 379                                $20 - $24.99 per hour
# 384                        $30 - $38 p.h. +  Holiday Pay
# 393                                           $45-$55000
# 398                                      $50000 - $54999
# 403                         Up-$23 p.h. + +  Holiday Pay
# 405                                       Up-$22.00 p.h.
# 430          NZD69726-94127p.a.+Retirement contributions
# 442                   $60k-$70k depending on experience!
# 444                                  $22.00 - $23.00 phr
# 455                                      $40000 - $49999
# 458                        $27 - $33 p.h. +  holiday pay
# 459                     $60K - $80K experience dependent
# 464                                     $19-$22 per hour
# 473      $60 - $65k + Career Progression-QS / leadership
# 478                                $35 - $39.99 per hour
# 482                                      $55000 - $64999
# 494       $20 - $24.99 per hour dependent on experience.
# 503                           Up-$27 p.h. +  Holiday Pay
# 517                                $20 - $24.99 per hour
# 530                               NZD19 - NZD23 per hour
# 532                                            $60000 pa
# 533                                      $40000 - $49999
# 536                        $21 - $25 p.h. +  Holiday Pay
# 546                                      $60000 - $69999
# 550                                     $21-$23 per hour
# 558                                      $50000 - $59999
# 560                                   $40 - $45 per hour
# 569                             $18.50 - $23.50 per hour
# 575                                                $25.5
# 578                           Up-$35 p.h. +  Holiday Pay
# 579                        $21 - $22 p.h. +  Holiday Pay
# 582                               NZD25 - NZD30 per hour
# 590                                $25 - $29.99 per hour
# 612                                      $50000 - $69999
# 625                                      $50000 - $59999
# 629                                $25 - $29.99 per hour
# 632                                      $50000 - $64999
# 633                                   $20 - $40 per hour
# 641                                      $48000 - $55000
# 644                    $50k - $65k p.a. + plus kiwisaver
# 650                                       $70-$80k+Super
# 653                                   $20 - $30 per hour
# 656                                      $45000 - $54999
# 660     $55000 - $65000 depending on relevant experience
# 663                                    $70-75k per annum
# 679              $45000 - $55000 depending on experience
# 682                       $24 - $28 p.h.  +  Holiday Pay
# 683                      $35 - $40 p.h. + +  Holiday Pay
# 695                                            Circa 50k
# 1936                      $24 - $28 p.h.  +  Holiday Pay
# 1937                     $35 - $40 p.h. + +  Holiday Pay
# 1949                                           Circa 50k
# Name: salary, dtype: object

# %%
df_admin['salary'].fillna('unknown')
# Out:
# 0       unknown
# 1       unknown
# 2       unknown
# 3       unknown
# 4       unknown
#          ...
# 2703    unknown
# 2704    unknown
# 2705    unknown
# 2706    unknown
# 2707    unknown
# Name: salary, Length: 2708, dtype: object

# %%
df_admin[df_admin['salary'].str.contains('\d',na=False)]['salary'].head(100)
# Out:
# 12                                          $20 per hour
# 17                                 $20 - $24.99 per hour
# 23                                      $19-$22 per hour
# 25                                 $20 - $24.99 per hour
# 36                                 $20 - $24.99 per hour
# 42                                       $40000 - $49999
# 48                                          $25 per hour
# 58                           $60 000 - $70 000 per annum
# 59                                       $20.00 per hour
# 66                                 $20 - $24.99 per hour
# 75                                       $55000 - $69999
# 77                                      $20.00 per hour.
# 78                                 $20 - $24.99 per hour
# 81                                          $21 per hour
# 82                                       $55000 - $64999
# 89                         $50000 - $55000 plus benefits
# 97                                       $45000 - $49999
# 103                   $55000 - $60000 per annum pro rata
# 112                                $20 - $24.99 per hour
# 114                                $20 - $24.99 per hour
# 123                                      $48835 - $63221
# 134                                $20 - $29.99 per hour
# 148                                              $24-$28
# 156                                             Up-$27ph
# 165                        $50000 - $55000 plus benefits
# 171                                $20 - $29.99 per hour
# 173                                $20 - $29.99 per hour
# 191                                $20 - $24.99 per hour
# 212                                      $55000 - $64999
# 214                                      $40000 - $49999
# 219                                      $45000 - $59999
# 231                               NZD25 - NZD28 per hour
# 247                                $20 - $24.99 per hour
# 264                                      $45000 - $49999
# 277                                         $22 per hour
# 278                                   NZD75000 per annum
# 282                                $20 - $24.99 per hour
# 306                                     $75k - $85k p.a.
# 311                            $24 - $25 +  holiday pay!
# 318                                      $40000 - $49999
# 319                                    $50000 per annum.
# 346                                      $55000 - $64999
# 349                                   $20 - $25 per hour
# 379                                $20 - $24.99 per hour
# 384                        $30 - $38 p.h. +  Holiday Pay
# 393                                           $45-$55000
# 398                                      $50000 - $54999
# 403                         Up-$23 p.h. + +  Holiday Pay
# 405                                       Up-$22.00 p.h.
# 430          NZD69726-94127p.a.+Retirement contributions
# 442                   $60k-$70k depending on experience!
# 444                                  $22.00 - $23.00 phr
# 455                                      $40000 - $49999
# 458                        $27 - $33 p.h. +  holiday pay
# 459                     $60K - $80K experience dependent
# 464                                     $19-$22 per hour
# 473      $60 - $65k + Career Progression-QS / leadership
# 478                                $35 - $39.99 per hour
# 482                                      $55000 - $64999
# 494       $20 - $24.99 per hour dependent on experience.
# 503                           Up-$27 p.h. +  Holiday Pay
# 517                                $20 - $24.99 per hour
# 530                               NZD19 - NZD23 per hour
# 532                                            $60000 pa
# 533                                      $40000 - $49999
# 536                        $21 - $25 p.h. +  Holiday Pay
# 546                                      $60000 - $69999
# 550                                     $21-$23 per hour
# 558                                      $50000 - $59999
# 560                                   $40 - $45 per hour
# 569                             $18.50 - $23.50 per hour
# 575                                                $25.5
# 578                           Up-$35 p.h. +  Holiday Pay
# 579                        $21 - $22 p.h. +  Holiday Pay
# 582                               NZD25 - NZD30 per hour
# 590                                $25 - $29.99 per hour
# 612                                      $50000 - $69999
# 625                                      $50000 - $59999
# 629                                $25 - $29.99 per hour
# 632                                      $50000 - $64999
# 633                                   $20 - $40 per hour
# 641                                      $48000 - $55000
# 644                    $50k - $65k p.a. + plus kiwisaver
# 650                                       $70-$80k+Super
# 653                                   $20 - $30 per hour
# 656                                      $45000 - $54999
# 660     $55000 - $65000 depending on relevant experience
# 663                                    $70-75k per annum
# 679              $45000 - $55000 depending on experience
# 682                       $24 - $28 p.h.  +  Holiday Pay
# 683                      $35 - $40 p.h. + +  Holiday Pay
# 695                                            Circa 50k
# 1936                      $24 - $28 p.h.  +  Holiday Pay
# 1937                     $35 - $40 p.h. + +  Holiday Pay
# 1949                                           Circa 50k
# Name: salary, dtype: object

# %%
df_admin['salary'].head(50)
# Out:
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12             $20 per hour
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17    $20 - $24.99 per hour
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23         $19-$22 per hour
# 24                      NaN
# 25    $20 - $24.99 per hour
# 26                      NaN
# 27                      NaN
# 28                      NaN
# 29                      NaN
# 30                      NaN
# 31                      NaN
# 32                      NaN
# 33                      NaN
# 34                      NaN
# 35                      NaN
# 36    $20 - $24.99 per hour
# 37                      NaN
# 38                      NaN
# 39                      NaN
# 40                      NaN
# 41                      NaN
# 42          $40000 - $49999
# 43                      NaN
# 44                      NaN
# 45                      NaN
# 46                      NaN
# 47                      NaN
# 48             $25 per hour
# 49                      NaN
# Name: salary, dtype: object

# %%
df_admin[['low_salary','high_salary']] = df_admin['salary'].str.split('-', n=1, expand = True).fillna('unknown')

# %%
df_admin[df_admin['high_salary'].str.contains('\d',na=False)]['high_salary'].head(100)
# Out:
# 17                                 $24.99 per hour
# 23                                    $22 per hour
# 25                                 $24.99 per hour
# 36                                 $24.99 per hour
# 42                                          $49999
# 58                               $70 000 per annum
# 66                                 $24.99 per hour
# 75                                          $69999
# 78                                 $24.99 per hour
# 82                                          $64999
# 89                            $55000 plus benefits
# 97                                          $49999
# 103                      $60000 per annum pro rata
# 112                                $24.99 per hour
# 114                                $24.99 per hour
# 123                                         $63221
# 134                                $29.99 per hour
# 148                                            $28
# 156                                          $27ph
# 165                           $55000 plus benefits
# 171                                $29.99 per hour
# 173                                $29.99 per hour
# 191                                $24.99 per hour
# 212                                         $64999
# 214                                         $49999
# 219                                         $59999
# 231                                 NZD28 per hour
# 247                                $24.99 per hour
# 264                                         $49999
# 282                                $24.99 per hour
# 306                                      $85k p.a.
# 311                            $25 +  holiday pay!
# 318                                         $49999
# 346                                         $64999
# 349                                   $25 per hour
# 379                                $24.99 per hour
# 384                        $38 p.h. +  Holiday Pay
# 393                                         $55000
# 398                                         $54999
# 403                      $23 p.h. + +  Holiday Pay
# 405                                    $22.00 p.h.
# 430             94127p.a.+Retirement contributions
# 442                  $70k depending on experience!
# 444                                     $23.00 phr
# 455                                         $49999
# 458                        $33 p.h. +  holiday pay
# 459                      $80K experience dependent
# 464                                   $22 per hour
# 473      $65k + Career Progression-QS / leadership
# 478                                $39.99 per hour
# 482                                         $64999
# 494       $24.99 per hour dependent on experience.
# 503                        $27 p.h. +  Holiday Pay
# 517                                $24.99 per hour
# 530                                 NZD23 per hour
# 533                                         $49999
# 536                        $25 p.h. +  Holiday Pay
# 546                                         $69999
# 550                                   $23 per hour
# 558                                         $59999
# 560                                   $45 per hour
# 569                                $23.50 per hour
# 578                        $35 p.h. +  Holiday Pay
# 579                        $22 p.h. +  Holiday Pay
# 582                                 NZD30 per hour
# 590                                $29.99 per hour
# 612                                         $69999
# 625                                         $59999
# 629                                $29.99 per hour
# 632                                         $64999
# 633                                   $40 per hour
# 641                                         $55000
# 644                     $65k p.a. + plus kiwisaver
# 650                                     $80k+Super
# 653                                   $30 per hour
# 656                                         $54999
# 660        $65000 depending on relevant experience
# 663                                  75k per annum
# 679                 $55000 depending on experience
# 682                       $28 p.h.  +  Holiday Pay
# 683                      $40 p.h. + +  Holiday Pay
# 1936                      $28 p.h.  +  Holiday Pay
# 1937                     $40 p.h. + +  Holiday Pay
# Name: high_salary, dtype: object

# %%
df_admin[df_admin['salary'].str.contains('\d',na=False)][['salary','low_salary','high_salary']]
# Out:
#                                                 salary          low_salary  \
# 12                                        $20 per hour        $20 per hour
# 17                               $20 - $24.99 per hour                $20
# 23                                    $19-$22 per hour                 $19
# 25                               $20 - $24.99 per hour                $20
# 36                               $20 - $24.99 per hour                $20
# 42                                     $40000 - $49999             $40000
# 48                                        $25 per hour        $25 per hour
# 58                         $60 000 - $70 000 per annum            $60 000
# 59                                     $20.00 per hour     $20.00 per hour
# 66                               $20 - $24.99 per hour                $20
# 75                                     $55000 - $69999             $55000
# 77                                    $20.00 per hour.    $20.00 per hour.
# 78                               $20 - $24.99 per hour                $20
# 81                                        $21 per hour        $21 per hour
# 82                                     $55000 - $64999             $55000
# 89                       $50000 - $55000 plus benefits             $50000
# 97                                     $45000 - $49999             $45000
# 103                 $55000 - $60000 per annum pro rata             $55000
# 112                              $20 - $24.99 per hour                $20
# 114                              $20 - $24.99 per hour                $20
# 123                                    $48835 - $63221             $48835
# 134                              $20 - $29.99 per hour                $20
# 148                                            $24-$28                 $24
# 156                                           Up-$27ph                  Up
# 165                      $50000 - $55000 plus benefits             $50000
# 171                              $20 - $29.99 per hour                $20
# 173                              $20 - $29.99 per hour                $20
# 191                              $20 - $24.99 per hour                $20
# 212                                    $55000 - $64999             $55000
# 214                                    $40000 - $49999             $40000
# 219                                    $45000 - $59999             $45000
# 231                             NZD25 - NZD28 per hour              NZD25
# 247                              $20 - $24.99 per hour                $20
# 264                                    $45000 - $49999             $45000
# 277                                       $22 per hour        $22 per hour
# 278                                 NZD75000 per annum  NZD75000 per annum
# 282                              $20 - $24.99 per hour                $20
# 306                                   $75k - $85k p.a.               $75k
# 311                          $24 - $25 +  holiday pay!                $24
# 318                                    $40000 - $49999             $40000
# 319                                  $50000 per annum.   $50000 per annum.
# 346                                    $55000 - $64999             $55000
# 349                                 $20 - $25 per hour                $20
# 379                              $20 - $24.99 per hour                $20
# 384                      $30 - $38 p.h. +  Holiday Pay                $30
# 393                                         $45-$55000                 $45
# 398                                    $50000 - $54999             $50000
# 403                       Up-$23 p.h. + +  Holiday Pay                  Up
# 405                                     Up-$22.00 p.h.                  Up
# 430        NZD69726-94127p.a.+Retirement contributions            NZD69726
# 442                 $60k-$70k depending on experience!                $60k
# 444                                $22.00 - $23.00 phr             $22.00
# 455                                    $40000 - $49999             $40000
# 458                      $27 - $33 p.h. +  holiday pay                $27
# 459                   $60K - $80K experience dependent               $60K
# 464                                   $19-$22 per hour                 $19
# 473    $60 - $65k + Career Progression-QS / leadership                $60
# 478                              $35 - $39.99 per hour                $35
# 482                                    $55000 - $64999             $55000
# 494     $20 - $24.99 per hour dependent on experience.                $20
# 503                         Up-$27 p.h. +  Holiday Pay                  Up
# 517                              $20 - $24.99 per hour                $20
# 530                             NZD19 - NZD23 per hour              NZD19
# 532                                          $60000 pa           $60000 pa
# 533                                    $40000 - $49999             $40000
# 536                      $21 - $25 p.h. +  Holiday Pay                $21
# 546                                    $60000 - $69999             $60000
# 550                                   $21-$23 per hour                 $21
# 558                                    $50000 - $59999             $50000
# 560                                 $40 - $45 per hour                $40
# 569                           $18.50 - $23.50 per hour             $18.50
# 575                                              $25.5               $25.5
# 578                         Up-$35 p.h. +  Holiday Pay                  Up
# 579                      $21 - $22 p.h. +  Holiday Pay                $21
# 582                             NZD25 - NZD30 per hour              NZD25
# 590                              $25 - $29.99 per hour                $25
# 612                                    $50000 - $69999             $50000
# 625                                    $50000 - $59999             $50000
# 629                              $25 - $29.99 per hour                $25
# 632                                    $50000 - $64999             $50000
# 633                                 $20 - $40 per hour                $20
# 641                                    $48000 - $55000             $48000
# 644                  $50k - $65k p.a. + plus kiwisaver               $50k
# 650                                     $70-$80k+Super                 $70
# 653                                 $20 - $30 per hour                $20
# 656                                    $45000 - $54999             $45000
# 660   $55000 - $65000 depending on relevant experience             $55000
# 663                                  $70-75k per annum                 $70
# 679            $45000 - $55000 depending on experience             $45000
# 682                     $24 - $28 p.h.  +  Holiday Pay                $24
# 683                    $35 - $40 p.h. + +  Holiday Pay                $35
# 695                                          Circa 50k           Circa 50k
# 1936                    $24 - $28 p.h.  +  Holiday Pay                $24
# 1937                   $35 - $40 p.h. + +  Holiday Pay                $35
# 1949                                         Circa 50k           Circa 50k
#
#                                      high_salary
# 12                                       unknown
# 17                               $24.99 per hour
# 23                                  $22 per hour
# 25                               $24.99 per hour
# 36                               $24.99 per hour
# 42                                        $49999
# 48                                       unknown
# 58                             $70 000 per annum
# 59                                       unknown
# 66                               $24.99 per hour
# 75                                        $69999
# 77                                       unknown
# 78                               $24.99 per hour
# 81                                       unknown
# 82                                        $64999
# 89                          $55000 plus benefits
# 97                                        $49999
# 103                    $60000 per annum pro rata
# 112                              $24.99 per hour
# 114                              $24.99 per hour
# 123                                       $63221
# 134                              $29.99 per hour
# 148                                          $28
# 156                                        $27ph
# 165                         $55000 plus benefits
# 171                              $29.99 per hour
# 173                              $29.99 per hour
# 191                              $24.99 per hour
# 212                                       $64999
# 214                                       $49999
# 219                                       $59999
# 231                               NZD28 per hour
# 247                              $24.99 per hour
# 264                                       $49999
# 277                                      unknown
# 278                                      unknown
# 282                              $24.99 per hour
# 306                                    $85k p.a.
# 311                          $25 +  holiday pay!
# 318                                       $49999
# 319                                      unknown
# 346                                       $64999
# 349                                 $25 per hour
# 379                              $24.99 per hour
# 384                      $38 p.h. +  Holiday Pay
# 393                                       $55000
# 398                                       $54999
# 403                    $23 p.h. + +  Holiday Pay
# 405                                  $22.00 p.h.
# 430           94127p.a.+Retirement contributions
# 442                $70k depending on experience!
# 444                                   $23.00 phr
# 455                                       $49999
# 458                      $33 p.h. +  holiday pay
# 459                    $80K experience dependent
# 464                                 $22 per hour
# 473    $65k + Career Progression-QS / leadership
# 478                              $39.99 per hour
# 482                                       $64999
# 494     $24.99 per hour dependent on experience.
# 503                      $27 p.h. +  Holiday Pay
# 517                              $24.99 per hour
# 530                               NZD23 per hour
# 532                                      unknown
# 533                                       $49999
# 536                      $25 p.h. +  Holiday Pay
# 546                                       $69999
# 550                                 $23 per hour
# 558                                       $59999
# 560                                 $45 per hour
# 569                              $23.50 per hour
# 575                                      unknown
# 578                      $35 p.h. +  Holiday Pay
# 579                      $22 p.h. +  Holiday Pay
# 582                               NZD30 per hour
# 590                              $29.99 per hour
# 612                                       $69999
# 625                                       $59999
# 629                              $29.99 per hour
# 632                                       $64999
# 633                                 $40 per hour
# 641                                       $55000
# 644                   $65k p.a. + plus kiwisaver
# 650                                   $80k+Super
# 653                                 $30 per hour
# 656                                       $54999
# 660      $65000 depending on relevant experience
# 663                                75k per annum
# 679               $55000 depending on experience
# 682                     $28 p.h.  +  Holiday Pay
# 683                    $40 p.h. + +  Holiday Pay
# 695                                      unknown
# 1936                    $28 p.h.  +  Holiday Pay
# 1937                   $40 p.h. + +  Holiday Pay
# 1949                                     unknown

# %%
df_admin['low_salary'] = df_admin['low_salary'].str.extract('(\d+\.\d+|\d+ \d+|\d+k|\d+)')
df_admin['high_salary'] = df_admin['high_salary'].str.extract('(\d+\.\d+|\d+ \d+|\d+k|\d+)')

# %%
df_admin[df_admin['low_salary'].str.contains('\d',na=False)]['low_salary'].head(100)
# Out:
# 12          20
# 17          20
# 23          19
# 25          20
# 36          20
# 42       40000
# 48          25
# 58      60 000
# 59       20.00
# 66          20
# 75       55000
# 77       20.00
# 78          20
# 81          21
# 82       55000
# 89       50000
# 97       45000
# 103      55000
# 112         20
# 114         20
# 123      48835
# 134         20
# 148         24
# 165      50000
# 171         20
# 173         20
# 191         20
# 212      55000
# 214      40000
# 219      45000
# 231         25
# 247         20
# 264      45000
# 277         22
# 278      75000
# 282         20
# 306        75k
# 311         24
# 318      40000
# 319      50000
# 346      55000
# 349         20
# 379         20
# 384         30
# 393         45
# 398      50000
# 430      69726
# 442        60k
# 444      22.00
# 455      40000
# 458         27
# 459         60
# 464         19
# 473         60
# 478         35
# 482      55000
# 494         20
# 517         20
# 530         19
# 532      60000
# 533      40000
# 536         21
# 546      60000
# 550         21
# 558      50000
# 560         40
# 569      18.50
# 575       25.5
# 579         21
# 582         25
# 590         25
# 612      50000
# 625      50000
# 629         25
# 632      50000
# 633         20
# 641      48000
# 644        50k
# 650         70
# 653         20
# 656      45000
# 660      55000
# 663         70
# 679      45000
# 682         24
# 683         35
# 695        50k
# 1936        24
# 1937        35
# 1949       50k
# Name: low_salary, dtype: object

# %%
df_admin['low_salary'] = df_admin[df_admin['low_salary'].str.contains('\d', na=False)]['low_salary'].str.replace('k', '000', regex=True)
df_admin['high_salary'] = df_admin[df_admin['high_salary'].str.contains('\d', na=False)]['high_salary'].str.replace('k', '000', regex=True)

# %%
pd.set_option('display.max_rows', 500)
df_admin[df_admin['low_salary'].str.contains('\d',na=False)]['low_salary'].head(100)
# Out:
# 12          20
# 17          20
# 23          19
# 25          20
# 36          20
# 42       40000
# 48          25
# 58      60 000
# 59       20.00
# 66          20
# 75       55000
# 77       20.00
# 78          20
# 81          21
# 82       55000
# 89       50000
# 97       45000
# 103      55000
# 112         20
# 114         20
# 123      48835
# 134         20
# 148         24
# 165      50000
# 171         20
# 173         20
# 191         20
# 212      55000
# 214      40000
# 219      45000
# 231         25
# 247         20
# 264      45000
# 277         22
# 278      75000
# 282         20
# 306      75000
# 311         24
# 318      40000
# 319      50000
# 346      55000
# 349         20
# 379         20
# 384         30
# 393         45
# 398      50000
# 430      69726
# 442      60000
# 444      22.00
# 455      40000
# 458         27
# 459         60
# 464         19
# 473         60
# 478         35
# 482      55000
# 494         20
# 517         20
# 530         19
# 532      60000
# 533      40000
# 536         21
# 546      60000
# 550         21
# 558      50000
# 560         40
# 569      18.50
# 575       25.5
# 579         21
# 582         25
# 590         25
# 612      50000
# 625      50000
# 629         25
# 632      50000
# 633         20
# 641      48000
# 644      50000
# 650         70
# 653         20
# 656      45000
# 660      55000
# 663         70
# 679      45000
# 682         24
# 683         35
# 695      50000
# 1936        24
# 1937        35
# 1949     50000
# Name: low_salary, dtype: object

# %%
df_admin['low_salary'] = df_admin[df_admin['low_salary'].str.contains('\d', na=False)]['low_salary'].str.replace(' ', '', regex=True)
df_admin['high_salary'] = df_admin[df_admin['high_salary'].str.contains('\d', na=False)]['high_salary'].str.replace(' ', '', regex=True)
df_admin['low_salary']=df_admin['low_salary'].fillna("unknown")
df_admin['high_salary']=df_admin['high_salary'].fillna("unknown")

# %%
df_admin.loc[df_admin['low_salary'] == 'unknown', 'low_salary'] = df_admin['high_salary']
df_admin.loc[df_admin['high_salary'] == 'unknown', 'high_salary'] = df_admin['low_salary']

# %%
import numpy as np
np.random.randint(45000,75000,size=1)
# Out:
# array([58494])

# %%
for r, row in enumerate(df_admin["low_salary"].values):
    if row == 'unknown':
        df_admin["low_salary"][r] = np.random.randint(45000,75000,size=1)[0]
# Out:
# /home/alfred/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for r, row in enumerate(df_admin["high_salary"].values):
    if row == 'unknown':
        df_admin["high_salary"][r] = max(np.random.randint(45000,75000,size=1)[0],df_admin["low_salary"][r] )
# Out:
# /home/alfred/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_admin[['low_salary','high_salary']]
# Out:
#      low_salary high_salary
# 0         69607       69607
# 1         70179       70179
# 2         74378       74378
# 3         54633       68467
# 4         48140       57407
# ...         ...         ...
# 2703      62515       62515
# 2704      68848       68848
# 2705      47248       73410
# 2706      60118       60118
# 2707      65669       70451
#
# [2708 rows x 2 columns]

# %%
df_admin['low_salary'] = df_admin['low_salary'].astype('float32')
df_admin['high_salary'] = df_admin['high_salary'].astype('float32')
df_admin.loc[df_admin['low_salary'] < 50, 'low_salary'] = df_admin['low_salary']*8*200
df_admin.loc[df_admin['high_salary'] < 50, 'high_salary'] = df_admin['high_salary']*8*200

# %%
df_admin.head(50)
# Out:
#                                             Job title  \
# 0                                       Administrator
# 1                                        Receptionist
# 2                        Prosecutions Support Officer
# 3                Early Childhood Centre Administrator
# 4                      Business Support Administrator
# 5                                     Support Officer
# 6                                     Support Officer
# 7                                office administrator
# 8                                Office Administrator
# 9                              Administration Officer
# 10                             Administration Officer
# 11                                         Data Entry
# 12            Office Admin Assistant (10hrs per week)
# 13                               Office Administrator
# 14                               Office Administrator
# 15                           Customer Service Officer
# 16           Administration Assistant - Mt Wellington
# 17  Part-time Health & Disability Administrative A...
# 18          Office Coordinator, Whangarei Youth Space
# 19                                      Administrator
# 20                 Administration Officer - Part Time
# 21                    Part-time Admin/Accounts Person
# 22                     Business Support Administrator
# 23                            Reception/Administrator
# 24                                Office Co-Ordinator
# 25                               Office Administrator
# 26                  Administration & Customer Service
# 27                                      Administrator
# 28                       RECEPTIONIST / ADMINISTRATOR
# 29                     Administrator - Street to Home
# 30                             Administrative Support
# 31                               Medical Receptionist
# 32               Receptionist / Office Administration
# 33                   People and Culture Administrator
# 34                             Senior Support Officer
# 35                                      Administrator
# 36                               office administrator
# 37   Provider Registration Administrator - Lower Hutt
# 38                       Receptionist / Admin Support
# 39  Colliers Rural - Office Administrator (Part time)
# 40                            Part Time Administrator
# 41                           Operations Administrator
# 42              Receptionist / Accounts Administrator
# 43                              Office Administrators
# 44                      Accounts and Office Assistant
# 45                  Administrator/Secretarial Support
# 46            Supporter Care & Database Administrator
# 47                   Personal Assistant/Administrator
# 48        Administrative and Organisational Superstar
# 49                                   Office Assistant
#
#                                               website  \
# 0   https://www.seek.co.nz/job/50582301?type=promo...
# 1   https://www.seek.co.nz/job/50620889?type=promo...
# 2   https://www.seek.co.nz/job/50622169?type=stand...
# 3   https://www.seek.co.nz/job/50639620?type=stand...
# 4   https://www.seek.co.nz/job/50622432?type=stand...
# 5   https://www.seek.co.nz/job/50640393?type=stand...
# 6   https://www.seek.co.nz/job/50615674?type=stand...
# 7   https://www.seek.co.nz/job/50640166?type=stand...
# 8   https://www.seek.co.nz/job/50639248?type=stand...
# 9   https://www.seek.co.nz/job/50629393?type=stand...
# 10  https://www.seek.co.nz/job/50600186?type=stand...
# 11  https://www.seek.co.nz/job/50616188?type=stand...
# 12  https://www.seek.co.nz/job/50597141?type=stand...
# 13  https://www.seek.co.nz/job/50632818?type=stand...
# 14  https://www.seek.co.nz/job/50632185?type=stand...
# 15  https://www.seek.co.nz/job/50614282?type=stand...
# 16  https://www.seek.co.nz/job/50638817?type=stand...
# 17  https://www.seek.co.nz/job/50610748?type=stand...
# 18  https://www.seek.co.nz/job/50633756?type=stand...
# 19  https://www.seek.co.nz/job/50604829?type=stand...
# 20  https://www.seek.co.nz/job/50637525?type=stand...
# 21  https://www.seek.co.nz/job/50631111?type=stand...
# 22  https://www.seek.co.nz/job/50591178?type=promo...
# 23  https://www.seek.co.nz/job/50556340?type=promo...
# 24  https://www.seek.co.nz/job/50632905?type=stand...
# 25  https://www.seek.co.nz/job/50621389?type=stand...
# 26  https://www.seek.co.nz/job/50637747?type=stand...
# 27  https://www.seek.co.nz/job/50631960?type=stand...
# 28  https://www.seek.co.nz/job/50636107?type=stand...
# 29  https://www.seek.co.nz/job/50638937?type=stand...
# 30  https://www.seek.co.nz/job/50606027?type=stand...
# 31  https://www.seek.co.nz/job/50633231?type=stand...
# 32  https://www.seek.co.nz/job/50620963?type=stand...
# 33  https://www.seek.co.nz/job/50617769?type=stand...
# 34  https://www.seek.co.nz/job/50628770?type=stand...
# 35  https://www.seek.co.nz/job/50613404?type=stand...
# 36  https://www.seek.co.nz/job/50621878?type=stand...
# 37  https://www.seek.co.nz/job/50638763?type=stand...
# 38  https://www.seek.co.nz/job/50621050?type=stand...
# 39  https://www.seek.co.nz/job/50615101?type=stand...
# 40  https://www.seek.co.nz/job/50628924?type=stand...
# 41  https://www.seek.co.nz/job/50631460?type=stand...
# 42  https://www.seek.co.nz/job/50638893?type=stand...
# 43  https://www.seek.co.nz/job/50628972?type=stand...
# 44  https://www.seek.co.nz/job/50564208?type=promo...
# 45  https://www.seek.co.nz/job/50529232?type=promo...
# 46  https://www.seek.co.nz/job/50623039?type=stand...
# 47  https://www.seek.co.nz/job/50638815?type=stand...
# 48  https://www.seek.co.nz/job/50633998?type=stand...
# 49  https://www.seek.co.nz/job/50623434?type=stand...
#
#                                        company name        location  \
# 0                                Private Advertiser   Bay of Plenty
# 1                              Avenues Orthodontics   Bay of Plenty
# 2                                New Zealand Police        Auckland
# 3          Kew Pacific Island Early Learning Centre       Southland
# 4                                Private Advertiser      Canterbury
# 5                   Ministry for Primary Industries       Northland
# 6   Ministry of Business, Innovation and Employment      Wellington
# 7                            Hepburn Electrical Ltd   Bay of Plenty
# 8                               Webster Holland Ltd   Bay of Plenty
# 9                                New Zealand Police      Canterbury
# 10                       Department of Conservation      West Coast
# 11                                  Triple One Care          Tasman
# 12   UIV Limited - Premier Insulation North Central        Auckland
# 13                      Wraight and Associates Ltd.      Wellington
# 14                  Morgan & Pollard Landscapes Ltd      Canterbury
# 15                                 CM Trailer Parts      Canterbury
# 16                                    Harvey Norman        Auckland
# 17                                         LIFEWISE        Auckland
# 18                            Whangarei Youth Space       Northland
# 19                               Private Advertiser        Manawatu
# 20                                  HiFlo Pumps Ltd        Auckland
# 21                                   People Passion        Auckland
# 22      S&L Land Development and Design Specialists   Bay of Plenty
# 23                Fishing and Leisure Group Limited        Auckland
# 24                         Paeroa Farm Services Ltd         Waikato
# 25                              Brant Homes Limited        Auckland
# 26                                              ACE        Auckland
# 27                     EnviroWaste Services Limited      Canterbury
# 28                        PROGRESSIVE MEATS LIMITED      Hawkes Bay
# 29                            Auckland City Mission        Auckland
# 30           Commercial and Rural Insurance Brokers           Otago
# 31                          Brooklyn Medical Centre      Wellington
# 32                         foley group architecture      Canterbury
# 33                     OceanaGold (New Zealand) Ltd           Otago
# 34                             WorkSafe New Zealand      Wellington
# 35                                       Wise Group         Waikato
# 36                              Best Mates Pet Food         Waikato
# 37                                              ACC      Wellington
# 38                                    STOP Services      Canterbury
# 39                                    Private Group   Bay of Plenty
# 40                                 Heyden Farms Ltd         Waikato
# 41                            Port Taranaki Limited        Taranaki
# 42                            Robertson Motor Group        Manawatu
# 43                                            SOLGM      Wellington
# 44                                  Geeks on Wheels      Wellington
# 45                                  The Heart Group        Auckland
# 46                                             SPCA        Auckland
# 47                       Department of Conservation      Wellington
# 48                             Grit Engineering Ltd       Northland
# 49                                       NetYourJob      Canterbury
#
#                                    area                  classification  \
# 0                              Tauranga               Office Management
# 1                              Tauranga                   Receptionists
# 2                               unknown                           Other
# 3                          Invercargill       Administrative Assistants
# 4                          Christchurch   Client & Sales Administration
# 5                             Whangarei       Administrative Assistants
# 6                    Wellington Central                           Other
# 7                               Rotorua       Administrative Assistants
# 8                              Tauranga       Administrative Assistants
# 9                               unknown                           Other
# 10                   Rest of West Coast       Administrative Assistants
# 11                               Nelson    Data Entry & Word Processing
# 12       Manukau & East AucklandManukau                         unknown
# 13                   Wellington Central               Office Management
# 14                   Rest of Canterbury       Administrative Assistants
# 15            Timaru & South Canterbury   Client & Sales Administration
# 16                     Auckland Central       Administrative Assistants
# 17          Auckland CentralAuckland Ce                         unknown
# 18                            Whangarei       Administrative Assistants
# 19                     Rest of Manawatu                           Other
# 20                     Auckland Central       Administrative Assistants
# 21                  Papakura & Franklin       Administrative Assistants
# 22                             Tauranga       Administrative Assistants
# 23       Rodney & North ShoreRodney & N                         unknown
# 24                      Rest of Waikato               Office Management
# 25   Manukau & East AucklandManukau & E                         unknown
# 26                     Auckland Central       Administrative Assistants
# 27                         Christchurch       Administrative Assistants
# 28                             Hastings       Administrative Assistants
# 29                     Auckland Central       Administrative Assistants
# 30                  Queenstown & Wanaka       Administrative Assistants
# 31                   Wellington Central       Administrative Assistants
# 32                         Christchurch                   Receptionists
# 33                        Rest of Otago   Client & Sales Administration
# 34                   Wellington Central       Administrative Assistants
# 35                             Hamilton       Administrative Assistants
# 36           Rest of WaikatoRest of Wai                         unknown
# 37                          Hutt Valley       Administrative Assistants
# 38                         Christchurch                   Receptionists
# 39                              Rotorua       Administrative Assistants
# 40                      Rest of Waikato       Administrative Assistants
# 41                         New Plymouth       Administrative Assistants
# 42            Palmerston NorthPalmersto                         unknown
# 43                   Wellington Central       Administrative Assistants
# 44                   Wellington Central       Administrative Assistants
# 45                     Auckland Central            PA, EA & Secretarial
# 46            Waitakere & West Auckland    Data Entry & Word Processing
# 47                   Wellington Central       Administrative Assistants
# 48                     WhangareiWhangar                         unknown
# 49            Timaru & South Canterbury       Administrative Assistants
#
#     posted time                 salary   classification1  \
# 0             0                    NaN   Administration
# 1             0                    NaN   Administration
# 2            -4                    NaN   Administration
# 3             0                    NaN   Administration
# 4            -4                    NaN   Administration
# 5          -270                    NaN   Administration
# 6            -5                    NaN   Administration
# 7          -210                    NaN   Administration
# 8             0                    NaN   Administration
# 9            -3                    NaN   Administration
# 10           -7                    NaN   Administration
# 11           -5                    NaN   Administration
# 12           -8           $20 per hour           unknown
# 13           -3                    NaN   Administration
# 14           -3                    NaN   Administration
# 15           -5                    NaN   Administration
# 16            0                    NaN   Administration
# 17           -6  $20 - $24.99 per hour           unknown
# 18           -3                    NaN   Administration
# 19           -7                    NaN   Administration
# 20           -2                    NaN   Administration
# 21           -3                    NaN   Administration
# 22            0                    NaN   Administration
# 23            0       $19-$22 per hour           unknown
# 24           -3                    NaN   Administration
# 25           -4  $20 - $24.99 per hour           unknown
# 26           -2                    NaN   Administration
# 27           -3                    NaN   Administration
# 28           -3                    NaN   Administration
# 29            0                    NaN   Administration
# 30           -6                    NaN   Administration
# 31           -3                    NaN   Administration
# 32           -4                    NaN   Administration
# 33           -5                    NaN   Administration
# 34           -3                    NaN   Administration
# 35           -5                    NaN   Administration
# 36           -4  $20 - $24.99 per hour           unknown
# 37            0                    NaN   Administration
# 38           -4                    NaN   Administration
# 39           -5                    NaN   Administration
# 40           -3                    NaN   Administration
# 41           -3                    NaN   Administration
# 42            0        $40000 - $49999           unknown
# 43           -3                    NaN   Administration
# 44            0                    NaN   Administration
# 45            0                    NaN   Administration
# 46           -4                    NaN   Administration
# 47            0                    NaN   Administration
# 48           -3           $25 per hour           unknown
# 49           -4                    NaN   Administration
#
#                    classification2  classification3  low_salary  high_salary
# 0    Office SupportAdministration    Office Support     69607.0      69607.0
# 1    Office SupportAdministration    Office Support     70179.0      70179.0
# 2    Office SupportAdministration    Office Support     74378.0      74378.0
# 3    Office SupportAdministration    Office Support     54633.0      68467.0
# 4    Office SupportAdministration    Office Support     48140.0      57407.0
# 5    Office SupportAdministration    Office Support     63270.0      63270.0
# 6    Office SupportAdministration    Office Support     61395.0      61395.0
# 7    Office SupportAdministration    Office Support     53345.0      60029.0
# 8    Office SupportAdministration    Office Support     67095.0      67095.0
# 9    Office SupportAdministration    Office Support     46630.0      50093.0
# 10   Office SupportAdministration    Office Support     55916.0      55916.0
# 11   Office SupportAdministration    Office Support     53090.0      72626.0
# 12                         unknown          unknown     32000.0      32000.0
# 13   Office SupportAdministration    Office Support     64147.0      64147.0
# 14   Office SupportAdministration    Office Support     64381.0      64381.0
# 15   Office SupportAdministration    Office Support     49616.0      72976.0
# 16   Office SupportAdministration    Office Support     49220.0      71074.0
# 17                         unknown          unknown     32000.0      39984.0
# 18   Office SupportAdministration    Office Support     64574.0      67663.0
# 19   Office SupportAdministration    Office Support     58894.0      58894.0
# 20   Office SupportAdministration    Office Support     63837.0      63837.0
# 21   Office SupportAdministration    Office Support     56651.0      56916.0
# 22   Office SupportAdministration    Office Support     54185.0      54185.0
# 23                         unknown          unknown     30400.0      35200.0
# 24   Office SupportAdministration    Office Support     71525.0      71525.0
# 25                         unknown          unknown     32000.0      39984.0
# 26   Office SupportAdministration    Office Support     59926.0      70832.0
# 27   Office SupportAdministration    Office Support     70695.0      70695.0
# 28   Office SupportAdministration    Office Support     64325.0      70107.0
# 29   Office SupportAdministration    Office Support     70719.0      70719.0
# 30   Office SupportAdministration    Office Support     63559.0      63559.0
# 31   Office SupportAdministration    Office Support     73412.0      73412.0
# 32   Office SupportAdministration    Office Support     52781.0      55560.0
# 33   Office SupportAdministration    Office Support     52308.0      52308.0
# 34   Office SupportAdministration    Office Support     68915.0      68915.0
# 35   Office SupportAdministration    Office Support     47947.0      60153.0
# 36                         unknown          unknown     32000.0      39984.0
# 37   Office SupportAdministration    Office Support     54925.0      54925.0
# 38   Office SupportAdministration    Office Support     50384.0      64438.0
# 39   Office SupportAdministration    Office Support     57959.0      68276.0
# 40   Office SupportAdministration    Office Support     49659.0      70949.0
# 41   Office SupportAdministration    Office Support     59000.0      59000.0
# 42                         unknown          unknown     40000.0      49999.0
# 43   Office SupportAdministration    Office Support     51040.0      54944.0
# 44   Office SupportAdministration    Office Support     69939.0      73951.0
# 45   Office SupportAdministration    Office Support     45053.0      55275.0
# 46   Office SupportAdministration    Office Support     50571.0      66078.0
# 47   Office SupportAdministration    Office Support     74612.0      74612.0
# 48                         unknown          unknown     40000.0      40000.0
# 49   Office SupportAdministration    Office Support     57333.0      57333.0
